# %%
# Step 1: Dataset
# -------------------------------
text = """
artificial intelligence is transforming modern society.
it is used in healthcare finance education and transportation.
machine learning allows systems to improve automatically with experience.
data plays a critical role in training intelligent systems.
large datasets help models learn complex patterns.
deep learning uses multi layer neural networks.
neural networks are inspired by biological neurons.
each neuron processes input and produces an output.
training a neural network requires optimization techniques.
gradient descent minimizes the loss function.

natural language processing helps computers understand human language.
text generation is a key task in nlp.
language models predict the next word or character.
recurrent neural networks handle sequential data.
lstm and gru models address long term dependency problems.
however rnn based models are slow for long sequences.

transformer models changed the field of nlp.
they rely on self attention mechanisms.
attention allows the model to focus on relevant context.
transformers process data in parallel.
this makes training faster and more efficient.
modern language models are based on transformers.

education is being improved using artificial intelligence.
intelligent tutoring systems personalize learning.
automated grading saves time for teachers.
online education platforms use recommendation systems.
technology enhances the quality of learning experiences.

ethical considerations are important in artificial intelligence.
fairness transparency and accountability must be ensured.
ai systems should be designed responsibly.
data privacy and security are major concerns.
researchers continue to improve ai safety.

text generation models can create stories poems and articles.
they are used in chatbots virtual assistants and content creation.
generated text should be meaningful and coherent.
evaluation of text generation is challenging.
human judgement is often required.

continuous learning is essential in the field of ai.
research and innovation drive technological progress.
students should build strong foundations in mathematics.
programming skills are important for ai engineers.
practical experimentation enhances understanding.

"""

# %%
# Step 2: Preprocessing

def preprocess_text(text):
    text = text.lower()
    text = text.replace('\n', ' ')
    tokens = text.split()
    return tokens

tokens = preprocess_text(text)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#Step 3: Create Input Sequences

# Initialize a tokenizer and fit it on the preprocessed tokens
tokenizer = Tokenizer()
tokenizer.fit_on_texts(tokens)

# Convert tokens to integer sequences using the tokenizer
token_list = tokenizer.texts_to_sequences([tokens])[0]

# Determine the total number of unique words in the vocabulary
total_words = len(tokenizer.word_index) + 1 # +1 for out-of-vocabulary words

input_sequences = []

for i in range(1, len(token_list)):
    n_gram_sequence = token_list[:i+1]
    input_sequences.append(n_gram_sequence)

max_len = max(len(seq) for seq in input_sequences)

input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# %%
# Step 4: Build RNN Model

model = Sequential()
model.add(Embedding(total_words, 50, input_length=max_len-1))
model.add(SimpleRNN(64))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Step 5: Train Model

model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.0019 - loss: 5.2758
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.0397 - loss: 5.1769
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.0781 - loss: 5.1071
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.1289 - loss: 5.0372
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.1554 - loss: 4.9680
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.2047 - loss: 4.8735
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.2216 - loss: 4.7920
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.2427 - loss: 4.6959
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.3101 - loss: 4.6011
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.3157 - loss: 4.4575
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.5050 - loss: 4.3468
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.3626 - loss: 4.2618
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.5068 - loss: 4.1549
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5184 - loss: 4.0168
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.5553 - loss: 3.9239
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.5498 - loss: 3.7887
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.6196 - loss: 3.6570
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7193 - loss: 3.5041
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.6769 - loss: 3.3956
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.7511 - loss: 3.2619
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7337 - loss: 3.1400
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.8368 - loss: 2.9725
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8321 - loss: 2.8440
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.8415 - loss: 2.7856
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8399 - loss: 2.6189
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8629 - loss: 2.5047
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8757 - loss: 2.3800
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9013 - loss: 2.2234
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9195 - loss: 2.1275
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9132 - loss: 2.0216
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9279 - loss: 1.9306
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9446 - loss: 1.8362
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9437 - loss: 1.7365
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9362 - loss: 1.6264
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.9466 - loss: 1.5552
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9695 - loss: 1.4416
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9749 - loss: 1.3573
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.9577 - loss: 1.3146
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.9872 - loss: 1.1831
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9808 - loss: 1.0990
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9883 - loss: 1.0425
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.9783 - loss: 1.0040
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9986 - loss: 0.9169
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.9981 - loss: 0.8840
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9986 - loss: 0.8146
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 1.0000 - loss: 0.7501
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.7241
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 1.0000 - loss: 0.7042
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.6344
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 1.0000 - loss: 0.6071
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 1.0000 - loss: 0.5632
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.5433
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 1.0000 - loss: 0.5002
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.4785
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.4556
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 0.4323
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.4011
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.3865
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.3674
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 0.3543
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.3361
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.3103
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.2949
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.2933
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.2726
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.2626
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.2552
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.2308
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 1.0000 - loss: 0.2332
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 1.0000 - loss: 0.2245
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 1.0000 - loss: 0.2170
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 1.0000 - loss: 0.2116
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.2022
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 1.0000 - loss: 0.1849
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 1.0000 - loss: 0.1865
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.1729
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 0.1781
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.1621
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 0.1551
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.1550
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 1.0000 - loss: 0.1472
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.1478
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.1410
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.1353
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 1.0000 - loss: 0.1357
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 1.0000 - loss: 0.1273
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 1.0000 - loss: 0.1204
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 0.1227
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 0.1173
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.1094
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.1103
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.1093
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.1035
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.1017
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.1001
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0992
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.0917
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 1.0000 - loss: 0.0922
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0883
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.0860
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0875
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.0807
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0807
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 1.0000 - loss: 0.0790
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 1.0000 - loss: 0.0750
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0769
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0732
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 0.0737
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 0.0703
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.0699
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0687
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0649
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 1.0000 - loss: 0.0639
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0648
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0617
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 1.0000 - loss: 0.0604
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0603
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0588
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0563
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0557
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0544
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0537
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 1.0000 - loss: 0.0524
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0529
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0507
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0497
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 0.0495
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0481
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0494
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0513
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0470
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0457
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0444
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0412
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 1.0000 - loss: 0.0406
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 1.0000 - loss: 0.0392
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 1.0000 - loss: 0.0380
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 1.0000 - loss: 0.0379
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0374
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0343
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 1.0000 - loss: 0.0351
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0319
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0311
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0308
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 1.0000 - loss: 0.0293
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0278
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0282
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0273
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 1.0000 - loss: 0.0265
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0258
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0236
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 1.0000 - loss: 0.0237
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0222
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0214
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 1.0000 - loss: 0.0210
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0204
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 1.0000 - loss: 0.0200
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 1.0000 - loss: 0.0198
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 1.0000 - loss: 0.0185

# %%
# Step 6: Text Generation
# -------------------------------
def generate_text(seed_text, next_words):
    for _ in range(next_words):
        sequence = tokenizer.texts_to_sequences([seed_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(sequence, verbose=0), axis=-1)

        for word, index in tokenizer.word_index.items():
            if index == predicted:
                seed_text += " " + word
                break
    return seed_text

# -------------------------------
# Step 7: Output
# -------------------------------
seed = "artificial intelligence"
print("Generated Text:")
print(generate_text(seed, 15))
# Out:
# Generated Text:
# artificial intelligence is transforming modern it is used in healthcare finance education and machine learning allows systems
